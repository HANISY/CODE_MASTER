# %%
text = "PyThOn"
convert = text.swapcase()
print(convert)
# Out:
# pYtHoN

# %%
text = "PyThOn"
convert = ""

for char in text:
    if char.isupper():
        convert += char.lower()
    elif char.islower():
        convert += char.upper()
    
print(convert)
# Out:
# pYtHoN

# %%
text = "PyThOn"
convert = ""

for char in text:
    if char.isupper():
        convert += char.lower()
    else:
        convert += char.upper()
    
print(convert)
# Out:
# pYtHoN

# %%
text = "python is fun"
output = reverse(text)

def reverse(word):
    spl_word = word.split()
    reversed_words = [word[::-1] for word in spl_word]
  
    return ' '.join(reversed_words)


print(output_result)
# Out:
# nohtyp si nuf

# %%
def encode(text):
    if not text: return ""
    a, b, c = [], text[0], 1
    for i in range(1, len(text)):
        if text[i] == b:
            c += 1
        else:
            a.extend([b, str(c)]); b, n = text[i], 1
    a.extend([b, str(c)])
    return "".join(a)

input1 = "aaabbc"
input2 = "aabbaa"

print(encode(input1))
print(encode(input2))
# Out:
# a3b4c4
# a2b3a4
